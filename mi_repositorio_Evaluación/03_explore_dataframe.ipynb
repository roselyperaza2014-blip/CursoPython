# %%
import pandas as pd

# %%
def read_csv_to_dataframe(file_path):
    df = pd.read_csv(file_path)
    return df

# %%
terminos_df = read_csv_to_dataframe("Event_core_v4.csv")

# %%
print(terminos_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   institution_code   29 non-null     object
#  1   event_date         29 non-null     object
#  2   event_id           29 non-null     object
#  3   parent_event_id    29 non-null     object
#  4   type               29 non-null     object
#  5   location_id        29 non-null     object
#  6   decimal_latitud    29 non-null     float64
#  7   decimal_longitude  29 non-null     float64
#  8   depth_m            29 non-null     int64
#  9   habitat            29 non-null     object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 2.4+ KB
# None

# %%
print(terminos_df.head(10))
# Out:
#   institution_code  event_date   event_id parent_event_id    type location_id  \
# 0           CIM-UH  30/05/2014  GG_GG01R1              GG  sample        GG01
# 1           CIM-UH  30/05/2014  GG_GG01R2              GG  sample        GG01
# 2           CIM-UH  30/05/2014  GG_GG01R3              GG  sample        GG01
# 3           CIM-UH  31/05/2014  GG_GG02R1              GG  sample        GG02
# 4           CIM-UH  03/06/2014  GG_GG04R1              GG  sample        GG04
# 5           CIM-UH  03/06/2014  GG_GG04R2              GG  sample        GG04
# 6           CIM-UH  03/06/2014  GG_GG04R3              GG  sample        GG04
# 7           CIM-UH  06/06/2014  GG_GG05R1              GG  sample        GG05
# 8           CIM-UH  06/06/2014  GG_GG05R2              GG  sample        GG05
# 9           CIM-UH  06/06/2014  GG_GG05R3              GG  sample        GG05
#
#    decimal_latitud  decimal_longitude  depth_m          habitat
# 0        22.239950         -84.732217       20       coral reef
# 1        22.239950         -84.732217       20       coral reef
# 2        22.239950         -84.732217       20       coral reef
# 3        22.430300         -84.538383       18       coral reef
# 4        22.306733         -84.672667       18       coral reef
# 5        22.306733         -84.672667       18       coral reef
# 6        22.306733         -84.672667       18       coral reef
# 7        21.925933         -84.808050        4  seagrass meadow
# 8        21.925933         -84.808050        4  seagrass meadow
# 9        21.925933         -84.808050        4  seagrass meadow

# %%
print(terminos_df.describe())
# Out:
#        decimal_latitud  decimal_longitude    depth_m
# count        29.000000          29.000000  29.000000
# mean         21.941785         -83.454216  11.448276
# std           0.326237           1.447654   9.026098
# min          21.567350         -84.813050   3.000000
# 25%          21.608783         -84.732217   4.000000
# 50%          21.925933         -84.433650   5.000000
# 75%          22.239950         -81.929400  18.000000
# max          22.430300         -81.582650  30.000000

# %%
print(terminos_df.columns)
# Out:
# Index(['institution_code', 'event_date', 'event_id', 'parent_event_id', 'type',
#        'location_id', 'decimal_latitud', 'decimal_longitude', 'depth_m',
#        'habitat'],
#       dtype='object')
