# %% [markdown]
# # **Final Project**

# %% [markdown]
# ### 1. Introduction

# %% [markdown]
# Thanatocenosis refers to the assemblage of organismal remains found in a given area without being buried or permanently incorporated into the layers of the lithosphere (Perea et al. 2018). However, in the literature, the term "death assemblages" is more commonly used, which essentially represents the same concept. Kidwell and Tomašových (2013) define death assemblages as the set of taxonomically identifiable organic remains found in the surface mixing layers of landscapes and seafloors.
#
# Marine mollusk death assemblages have been among the most extensively studied, resulting in a vast body of literature on the subject (e.g., Kidwell and Bosence 1991; Kidwell and Flessa 1996; Kowalewski et al. 1998; Grill and Zuschin 2001; Weber and Zuschin 2013; Chattopadhyay et al. 2021; Steger et al. 2022; Albano et al. 2023). The following is a summary of the benefits identified in studies of marine benthic mollusk death assemblages:
#
# * They provide an efficient alternative for estimating species richness due to the high diversity and abundance of shells that can be found in relatively few sediment samples. To study the diversity of a living community, multiple sampling events and large sample sizes are usually required. Owing to time averaging (co-occurrence of shells belonging to several generations), death assemblages often better represent the regional diversity of species than any single living community.
# * They have been used to explore diversity in marine habitats such as coral reefs and seagrass beds, as they characterize a type of habitat more effectively than a single census of living species.
# * There is high fidelity between living and dead organisms, as it has been observed that most dead shells (80–95%) belong to species also observed alive (Kidwell and Flessa 1996). The greater the proportion of taxa with biomineralized structures (calcite, aragonite, or chitin), the higher the fidelity between the thanatocoenosis and the living community of a given site (Kidwell and Bosence 1991).
# * The same sampling and data analysis methods are used as in studies of living communities.
# * Large quantities of sediment or the collection of living organisms are not required, making these studies generally less invasive for ecosystems.
#
# Therefore, the thanatocoenosis are a useful tool for assessing mollusk diversity patterns in extensive regions and/or in areas with limited monitoring of the group. The objectives of the this project were: (i) to evaluate the contribution of death assemblages to the total mollusk community in coral reefs and seagrass beds from two gulfs in the western Cuban Archipelago, the Gulf of Batabanó (GB) and the Gulf of Guanahacabibes (GG) (Figure 1). And, (ii) to compare the species richness of mollusk death assemblages between habitats and gulfs.

# %% [markdown]
# ![Figure 1](mi_repositorio_Evaluación/Imagen1.jpg)

# %%
from PIL import Image
img = Image.open("Imagen1.jpg")
img.show()  # Open the image using the default image viewer

# %% [markdown]
# ### 2. Analysis and Results

# %% [markdown]
# ##### Obj. 1_Contribution of mollusk death assemblages:

# %% [markdown]
# I compared the mollusk thanatocoenosis (Peraza-Escarrá et al. 2024) and biocoenosis (reported in Armenteros et al. 2018) from the same sampling units, with the aim of assessing the relative contribution of thanatocoenosis to the abundance and species richness of the total mollusk community. For this purpose, replicates at each site were pooled, and the following formulae were applied:

# %% [markdown]
# $$
# (1) N\% = \frac{N_{dead}}{N_{dead} + N_{live}} \times 100
# $$

# %% [markdown]
# $$
# (2) S\% = \frac{S_{dead}}{S_{total}} \times 100
# $$

# %% [markdown]
# Where:
# - **N%**: relative contribution of the thanatocoenosis to the total species abundance.
# - **N_dead**: number of dead individuals.
# - **N_live**: number of living individuals.
# - **S%**: relative contribution of the thanatocoenosis to the total species richness.
# - **S_total**: species richness including both living and dead individuals.
# - **S_dead**: species richness of the thanatocoenosis.

# %%
import pandas as pd
from tabulate import tabulate

data = {
    "Site": ["GB09","GB10","GB11","GB12","GG01","GG02","GG04","GG05","GG06","GG09","GG14"],
    "Habitat": ["coral_reef","seagrass","coral_reef","seagrass","coral_reef","coral_reef","coral_reef","seagrass","seagrass","seagrass","seagrass"],
    "N_live": [5,10,23,6,10,1,17,13,17,26,20],
    "N_dead": [1553,744,1118,355,364,139,660,752,576,474,378],
    "S_live": [5,5,6,4,8,1,6,6,5,9,9],
    "S_dead": [181,79,166,55,83,40,142,83,58,71,68],
    "S_total": [182,79,170,58,86,40,145,86,61,78,73]
}

df = pd.DataFrame(data)

df["N_percent"] = df["N_dead"] / (df["N_dead"] + df["N_live"]) * 100
df["S_percent"] = df["S_dead"] / df["S_total"] * 100

print(tabulate(df, headers='keys', tablefmt='github', showindex=False))

df.to_csv("mollusk_data_analysis.csv", index=False)
# Out:
# | Site   | Habitat    |   N_live |   N_dead |   S_live |   S_dead |   S_total |   N_percent |   S_percent |
# |--------|------------|----------|----------|----------|----------|-----------|-------------|-------------|
# | GB09   | coral_reef |        5 |     1553 |        5 |      181 |       182 |     99.6791 |     99.4505 |
# | GB10   | seagrass   |       10 |      744 |        5 |       79 |        79 |     98.6737 |    100      |
# | GB11   | coral_reef |       23 |     1118 |        6 |      166 |       170 |     97.9842 |     97.6471 |
# | GB12   | seagrass   |        6 |      355 |        4 |       55 |        58 |     98.338  |     94.8276 |
# | GG01   | coral_reef |       10 |      364 |        8 |       83 |        86 |     97.3262 |     96.5116 |
# | GG02   | coral_reef |        1 |      139 |        1 |       40 |        40 |     99.2857 |    100      |
# | GG04   | coral_reef |       17 |      660 |        6 |      142 |       145 |     97.4889 |     97.931  |
# ...

# %% [markdown]
# The results showed the high contribution (> 90%) of death assemblages to the abundance and species richness of the total mollusk community. It was confirmed that death assemblages have higher species richness than any single census of living species, which is explained by the accumulation of shells from different generations over time (time averaging) (Kidwell and Bosence 1991).
#
# Many species found exclusively in the thanatocoenosis are not allochthonous or exotic, but have simply not yet been collected alive, possibly due to their aggregated distribution or the ephemeral nature of their populations (Kidwell 2008). On the other hand, some species from the biocoenosis did not occur in the thanatocoenosis at the same site, but were observed in the thanatocoenosis of other sites within the same gulf. It was also observed that a few species exclusive to the biocoenosis of one gulf were present in the thanatocoenosis of the other gulf (e.g., *Angulus* sp., *Atys* spp., *Caecum* spp., and *Phlyctiderma semiasperum*). All of this indicates that species “absent” in the local thanatocoenosis were present in the regional species pool.

# %% [markdown]
# ##### Obj. 2_Comparison of species richness richness of mollusk death assemblages:

# %% [markdown]
# For the comparison of the species richness of mollusk death assemblages, I built accumulation curves versus individuals using the effective number of species (Hill’s number 0) (Hill 1973). The accumulation curves included the observed richness and 0.95 confidence intervals (CIs) generated by 500 permutations using the package inext in the R package iNEXT 3.0.0 (Hsieh et al. 2016).

# %%
import pandas as pd

def read_csv_to_dataframe(file_path: str) -> pd.DataFrame:
    try:
        df = pd.read_csv(file_path)
        return df
    except Exception as e:
        print(f"Error reading CSV file: {e}")
        return pd.DataFrame()
Curves_df = read_csv_to_dataframe("Curves_data.csv")
print(Curves_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80 entries, 0 to 79
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Assemblage   80 non-null     object
#  1   Gulf         80 non-null     object
#  2   Habitat      80 non-null     object
#  3   Individuals  80 non-null     int64
#  4   Order.q      80 non-null     int64
#  5   qD           80 non-null     float64
#  6   qD.LCL       80 non-null     float64
#  7   qD.UCL       80 non-null     float64
# dtypes: float64(3), int64(2), object(3)
# memory usage: 5.1+ KB
# None

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("Curves_data.csv")  

plt.figure(figsize=(12,6))

colors = {"Coral Reef":"orange", "Seagrass":"green"}

for (gulf, habitat), group in df.groupby(["Gulf", "Habitat"]):
    plt.plot(group["Individuals"], group["qD"], color=colors[habitat], label=f"{gulf} - {habitat}")
    plt.fill_between(group["Individuals"], group["qD.LCL"], group["qD.UCL"], color=colors[habitat], alpha=0.2)

plt.xlabel("Individuals (N)")
plt.ylabel("Species richness (qD)")
plt.title("Accumulation curves of mollusk death assemblages")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# The habitat type have a strong influence on the species richness, which agrees
# with reports about death and live mollusks assemblages (Weber and Zuschin 2013; Zuschin and Ebner 2015; Armenteros et al. 2018). Coral reef harbor a higher species richness of mollusks death assemblages. The balance between productivity and disturbance (Huston 1994) may explain this result. Coral reefs function upon high quality organic carbon, which is eventually available to consumers (e.g., herbivore or carnivore mollusks) (Cote and Knowlton 2013). Also, in coral reefs the physical disturbance by waves and currents reduces oxygen depletion, which is a limiting factor for mollusks. Seagrass meadows harbor a large biodiversity as well, but their balance productivity-disturbance is likely less favorable compared to reef sands explaining the lower richness.

# %% [markdown]
# ### 3. Cited literature

# %% [markdown]
# Note. To order the literature alphabetically: Ctrl+Shift+P → escribir "Sort" Lines Ascending

# %% [markdown]
# * Albano PG, Hua Q, Kaufman DS, Zuschin M. 2023. Young death assemblages with limited time-averaging in rocky and Posidonia oceanica habitats in the Mediterranean Sea. Geol Soc Spec Publ 529: SP529–2022. https://doi.org/10.1144/SP529-2022-224
# * Armenteros M, Saladrigas D, González-Casuso L, Estevez ED, Kowalewski M. 2018. The role of habitat selection on the diversity of macrobenthic communities in three gulfs of the Cuban Archipelago. Bull Mar Sci 94: 249–68. https://doi.org/10.5343/bms.2017.1013
# * Chattopadhyay D, Sarkar D, Bhattacherjee M. 2021. The distribution pattern of marine bivalve death assemblage from the western margin of Bay of Bengal and its oceanographic determinants. Front Mar Scie 8: 675344. https://doi.org/10.3389/fmars.2021.675344
# * Cote IM, Knowlton N. 2013. Coral reef ecosystems: a decade of discoveries. In: Bertness MD, Bruno JF, Silliman BR, Stachowicz JJ, editors. Marine community ecology and conservation. Sunderland: Sinauer Associates, Pp. 299–314.
# * Grill B, Zuschin M. 2001. Modern shallow-to deep-water bivalve death assemblages in the Red Sea—ecology and biogeography. Palaeogeogr Palaeoclimatol Palaeoecol 16: 75–96. https://doi.org/10.1016/S0031-0182(00)00250-9
# * Hill MO. 1973. Diversity and evenness: a unifying notation and its consequences. Ecology 54: 427–32. https://doi.org/10.2307/1934352
# * Hsieh TC, Ma KH, Chao A. 2016. iNEXT: an R package for rarefaction and extrapolation of species diversity (Hill numbers). Methods Ecol Evol 7: 1451–1456. https://doi.org/10.1111/2041-210X.12613
# * Huston M. 1994. Biological diversity—The coexistence of species. Cambridge University Press. 681 p.
# * Kidwell SM, Bosence D. 1991. Taphonomy and time-averaging of marine shelly faunas. In: Allison PA, Briggs D (Eds.) Taphonomy: Releasing the data locked in the fossil record. Plenum Publishers, Pp. 115–209.
# * Kidwell SM, Flessa KW. 1996. The quality of the fossil record: populations, species, and communities. Ann Rev Earth Planet Sci 24: 433–464. https://www.jstor.org/stable/2097208
# * Kidwell SM, Tomašových A. 2013. Implications of time-averaged death assemblages for ecology and conservation biology. Annu Rev Ecol Evol Syst 44: 539–563. https://doi.org/10.1146/annurev-ecolsys-110512-135838
# * Kidwell SM. 2008. Ecological fidelity of open marine molluscan death assemblages: effects of post mortem transportation, shelf health, and taphonomic inertia. Lethaia 4: 199–217. https://doi.org/10.1111/j.1502-3931.2007.00050.x
# * Kowalewski M, Goodfriend G, Flessa K. 1998. High-Resolution Estimates of Temporal Mixing within Shell Beds: The Evils and Virtues of Time-Averaging. Paleobiology 24: 287–304.
# * Peraza-Escarrá R, Armenteros M, Fernández-Garcés R, Gracia A. 2024. Taxonomic, phylogenetic, and functional diversity of mollusk death assemblages in coral reef and seagrass sediments from two shallow gulfs in Western Cuban Archipelago. Plos one 19: e0303539. https://doi.org/10.1371/journal.pone.0303539
# * Perea D, Cabrera F, Corona A, Daners G, Martínez S, Mesa V, Rojas A, Soto M, Ubilla M, Verde M. 2018. Fundamentos de paleontología. Montevideo, Comisión Sectorial de Enseñanza.
# * Steger J, Bošnjak M, Belmaker J, Galil BS, Zuschin M, Albano PG. 2022. Non‐indigenous molluscs in the Eastern Mediterranean have distinct traits and cannot replace historic ecosystem functioning. Glob Ecol Biogeogr 31: 89–102.  https://doi.org/10.1111/geb.13415
# * Weber K, Zuschin M. 2013. Delta-associated molluscan life and death assemblages in the northern Adriatic Sea: implications for paleoecology, regional diversity and conservation. Palaeogeogr Palaeoclimatol Palaeoecol 370: 77–91. https://doi.org/10.1016/j.palaeo.2012.11.021
# * Zuschin M, Ebner C. 2015. Compositional fidelity of death assemblages from a coral reef-associated tidal-flat and shallow subtidal lagoon in the northern Red Sea. Palaios 30: 181–191. https://doi.org/10.2110/palo.2014.032
